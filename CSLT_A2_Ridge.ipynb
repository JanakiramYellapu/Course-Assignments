# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
train_df = pd.read_csv("/content/kc_house_train_data.csv")
test_df = pd.read_csv("/content/kc_house_test_data.csv")

# %%
# making a copy of df and preprocessing on whole  data
data = train_df.append(test_df,ignore_index= True, sort = False)
print("Shape of test + train data : ",data.shape)
# Out:
# Shape of test + train data :  (21613, 21)

# %%
# Dividing data into test and train data
train, test = train_test_split(data, train_size =0.8043307268773423, random_state = 3)

# separting labels from train and test data 
x_train = train.drop(labels = ["date","id","price"],axis = 1)
y_train = train["price"]
x_test = test.drop(labels = ["date","id","price"],axis = 1)
y_test = test["price"]

x_train = x_train.to_numpy()
y_train = y_train.to_numpy().reshape(x_train.shape[0],1)
x_test = x_test.to_numpy()
y_test = y_test.to_numpy().reshape(x_test.shape[0],1)

# %%
print("X_train_shape : ",x_train.shape)
y_test.shape
# Out:
# X_train_shape :  (17384, 18)
# (4229, 1)

# %%
# Initializing weights
m = x_train.shape[0]
no_of_features = x_train.shape[1]
# w = np.random.rand(1,no_of_features)
w = [-2.14170896e+04,  1.45144058e+04,  1.34751092e+02,  6.82530261e-02,
        1.23060765e+04,  6.93346573e+03,  3.40318972e+04,  7.77805146e+03,
        5.57444540e+04,  7.14453448e+01,  6.33057472e+01, -2.73549381e+03,
        2.89431365e+01,  1.69748245e+02,  1.74368410e+04, -4.79131759e+03,
        6.58660295e+01, -6.42738001e-01]
b = 0;


iterations = 1
for i in range(iterations):
  for i in range(m):
    y = np.dot(w,x_train.T[:,i]) +b 

    # loss function

    L = (1/2) * (y - y_train[i])**2

    dw = (y - y_train[i]) * x_train.T[:,i]
    db = (y.T - y_train[i])
    # Gradient Descent
    lr = 0.0001
    w = w - lr * dw
    b = b - lr * db
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in square
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: RuntimeWarning: overflow encountered in multiply
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in multiply
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in subtract

# %%
# Out:
# array([nan])
